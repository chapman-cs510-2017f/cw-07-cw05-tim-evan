# %%
import matplotlib.pyplot as plt
import numpy as np
import julia_plane as jp

# %%
z =  -0.835 - 0.2321j

myplane = jp.JuliaPlane(z)
myplane.show()

# %%
z = -1.037 + 0.17j
myplane.refresh(z)
myplane.show()
