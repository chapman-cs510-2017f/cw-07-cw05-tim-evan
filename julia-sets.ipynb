# %%
import matplotlib.pyplot as plt
import numpy as np
import julia_plane as jp

# %%
x = -1
y = 0
z = complex(x,y)

myplane = jp.JuliaPlane(z)
#myplane.printPlane()
myplane.show()

# %%
Tim, try different values for x and y above, it works
